# %%
import sys
sys.path.append('/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan')
from app.views import solve_LP
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rssi = {0:{31:-30}, 31:{0:-30}}
def p(i):
    return {0:1,31:i}
px = {0:1,31:0.000005}
code = """class SenseReduce:
    def __init__(self):
        self.sensenodes = [[31]]
        self.mapnodes = [[31,0]]
        self.reducenodes = [[31,0]]
        self.l={}
    def sampler(self,node):
        acc = yield from node.testaccel({})
        return (node.ID,acc['x'])
    def mapper(self,node,d):
        fts = np.fft(d[1])
        c = lambda d: (d.real,d.imag)
        sort = lambda fts: sorted(enumerate(fts), key=lambda x: abs(x[1]), reverse=True)[0:210]
        largest_idxs= [(i[0], c(i[1])) for i in sort(fts)]
        yield(0,largest_idxs)
    def reducer(self,node,k,vs):
        yield(k,vs)"""
code1 = """class SenseReduce:
    def __init__(self):
        self.sensenodes = [[31]]
        self.mapnodes = [[31]]
        self.reducenodes = [[31,0]]
        self.l={}
    def sampler(self,node):
        acc = yield from node.testaccel({})
        return (node.ID,acc['x'])
    def mapper(self,node,d):
        fts = np.fft(d[1])
        c = lambda d: (d.real,d.imag)
        sort = lambda fts: sorted(enumerate(fts), key=lambda x: abs(x[1]), reverse=True)[0:210]
        largest_idxs= [(i[0], c(i[1])) for i in sort(fts)]
        yield(0,largest_idxs)
    def reducer(self,node,k,vs):
        yield(k,vs)"""
code2 = """class SenseReduce:
    def __init__(self):
        self.sensenodes = [[31]]
        self.mapnodes = [[0]]
        self.reducenodes = [[31,0]]
        self.l={}
    def sampler(self,node):
        acc = yield from node.testaccel({})
        return (node.ID,acc['x'])
    def mapper(self,node,d):
        fts = np.fft(d[1])
        c = lambda d: (d.real,d.imag)
        sort = lambda fts: sorted(enumerate(fts), key=lambda x: abs(x[1]), reverse=True)[0:210]
        largest_idxs= [(i[0], c(i[1])) for i in sort(fts)]
        yield(0,largest_idxs)
    def reducer(self,node,k,vs):
        yield(k,vs)"""
def run3(f):
    def runner(*args,**kw):
        res = [f(*args,**kw)['totaltime'] for i in range(3)]
        print('res: ',res)
        return sum(res)/len(res)
    return runner
def get_all(code,rssi):
    speeds = [0.00000250,0.00000500,0.00000750, 0.00001000, 0.00001250, 0.00001500, 0.00001750] 
    speeds = [100*i for i in speeds]
    res = [(i,run3(solve_LP)(code, rssi=rssi, proc = p(i)) )
           for i in speeds]
    return [(i[0],i[1]) for i in res]
ranger = get_all(code1.format(512,512),rssi)
ranger2 = get_all(code2.format(512,512),rssi)
ranger_opt = get_all(code.format(512,512), rssi)
# Out:
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 277.71812597872497, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.448999999996374, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.006999999996537554, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 346.40023098275014, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.766999999998745, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.005999999999062311, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 361.75864436256074, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.9269999999997935, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.007000000003642981, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 320.0885550470747, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.653999999999826, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.005999999999062311, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 281.30769816265433, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.931999999994275, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.007000000003642981, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 267.80576039361716, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.649999999995714, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.005000000001587068, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# res:  [101005.34336114669, 100527.03168521533, 100458.74789054543]
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 366.5167726691386, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.82899999999853, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.006000000006167738, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 377.8454357667798, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.656000000001882, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.005999999999062311, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 264.16668245724355, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.831999999998061, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.005999999999062311, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost':
 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.8000000000006935, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.005999999999062311, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 376.7674314222098, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.690000000001305, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.006000000006167738, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 301.11829726130213, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.94300000000203, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.005999999999062311, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 340.43644873332784, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.8300000000031105, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.006000000006167738, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 359.0044158342489, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.884999999999252, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.005999999999062311, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# ...
# weights:  {'S': {0: {'cost': 258.3480947036831, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.179000000003043, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.006999999996537554, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 344.4007687993113, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.821999999994887, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.004999999994481641, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 275.0006012127324, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.016000000002464, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.006999999996537554, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 334.5981397873671, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.092999999999904, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.006999999996537554, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 354.7656051035674, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.022999999999001, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.008999999998593466, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 349.5455873988061, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.208999999998355, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.008999999998593466, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# res:  [83645.71010047424, 83636.18047146231, 83651.24591907376]
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 295.95138944082555, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.444000000001893, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.006999999996537554, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 361.7381371743668, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.9340000000034365, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.005999999999062311, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 344.4989410529015, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.228999999997598, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.006999999996537554, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 353.16978352191705, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.089000000002898, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.008999999998593466, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 338.0170517720012, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.164999999995757, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.00999999999606871, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 375.3509692995483, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.103000000003078, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.008000000001118224, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# res:  [82699.88126734608, 82815.31591369318, 82848.69609947098]
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 311.7738525122419, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.333999999995399, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.008000000001118224, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 357.57479300948705, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.127999999996803, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.008000000001118224, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 269.1079777404721, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.093999999997379, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.007000000003642981, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 307.6779323055205, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.848000000000297, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.008000000001118224, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 265.8620069507392, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.828000000001055, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.005999999999062311, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 343.85800557577556, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.709000000003073, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.005999999999062311, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# res:  [82033.85325650965, 81797.28972914135, 81740.80113574679]
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 280.07897232903633, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.019000000001995, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.007000000003642981, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 258.28062066517134, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.851999999997304, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.007000000003642981, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 307.03376886555844, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.0259999999985325, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.006999999996537554, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 261.2575764018592, 'edge': {0: 10995}}}, 'M': {0: {'cost': 5.735999999998853, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.005999999999062311, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 260.9047096396321, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.104999999998029, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.007000000003642981, 'edge': {0: 10244}}}}
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# opening:  /home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/192.168.123.99.json
# called emulator!! <module 'app.np' from '/home/james/Dropbox (MIT)/All_Resourceful/dag_planner/dag-plan/app/np.py'>
# weights:  {'S': {0: {'cost': 263.898371234121, 'edge': {0: 10995}}}, 'M': {0: {'cost': 6.089000000002898, 'edge': {0: 10242}}}, 'R': {0: {'cost': 0.007999999994012796, 'edge': {0: 10244}}}}
# rssi graph:  {0: {31: -30}, 31: {0: -30}}
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# prob success:  0.9899999132339502
# time per try:  300 num_tries:  1.01010109862877
# time per byte:  7.575758239715775
# trying to solve
# res:  [81193.2247508326, 81129.91499228445, 81334.2720728333]

# %%
fig, ax = plt.subplots(1)
ax.plot([x[0] for x in ranger], [y[1] for y in ranger], c='b', linewidth=0.1, marker='o')
ax.plot([x[0] for x in ranger2], [y[1] for y in ranger2], c='r',linewidth=0.1, marker='o')
ax.plot([x[0] for x in ranger2], [y[1] for y in ranger_opt], c='k',linewidth=0.1, marker='o')
sns.despine()

# %%
(0.00000250*15)*3e9
# Out:
# 112500.00000000001

# %%
0.00125*3*1e9
# Out:
# 3750000.0

# %%
0.0006/0.03
# Out:
# 0.02

# %%
396*0.02
# Out:
# 7.92

# %%
512/4
# Out:
# 128.0

# %%
100*0.0000125/0.02
# Out:
# 0.0625
